# %% [markdown]
# # TAMU Datathon 2021 :: Bloomberg INDG Challenge

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
BASE_DIR = '/content/drive/MyDrive/TAMU Datathon/Fed Topic Model/indg-fed-register/'

# %% [markdown]
# ## Imports

# %%
import numpy as np
import glob
import os
from tqdm import tqdm

from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF

# %% [markdown]
# ##How to efficiently extract SUBJECT, SUM (summary), SUPLINF text from XML files for each year?

# %%
# There are 3618 XML files in the docs folder
print(len([name for name in os.listdir(BASE_DIR+r"docs") if os.path.isfile(os.path.join(BASE_DIR+r"docs", name))]))
# Out:
# 3618

# %%
# Find the most efficient way to get content from the set of XML files for each year
count = 0
for s in ['01', '02', '03', '04', '05', '06', '07', '08', '09']:
    local = 0
    filelist = glob.glob(BASE_DIR+f"docs/{s}-*.xml")
    count += len(filelist)
    local += count

    filelist = glob.glob(BASE_DIR+f"docs/E{s[1]}*.xml")
    count += len(filelist)
    print(s, local)

for i in range(2010, 2022):
    local = 0
    s = str(i)
    filelist = glob.glob(BASE_DIR+f"docs/{s}-*.xml")
    count += len(filelist)
    local += len(filelist)

    filelist = glob.glob(BASE_DIR+f"docs/C1-{s}-*.xml")
    count += len(filelist)
    local += len(filelist)
    filelist = glob.glob(BASE_DIR+f"docs/C2-{s}-*.xml")
    count += len(filelist)
    local += len(filelist)
    filelist = glob.glob(BASE_DIR+f"docs/R1-{s}-*.xml")
    count += len(filelist)
    local += len(filelist)

    print(s, local)
# print(count)

filelist = glob.glob(BASE_DIR+f"docs/R3-*.xml") # 2003, only 1 file
count += len(filelist)
print(count) # 3617 files and 1 file is a very short amendment file
# Out:
# 01 170
# 02 305
# 03 461
# 04 628
# 05 743
# 06 817
# 07 896
# 08 1014
# 09 1177
# 2010 201
# 2011 253
# 2012 203
# 2013 170
# 2014 181
# 2015 156
# 2016 189
# 2017 128
# 2018 188
# 2019 239
# 2020 286
# 2021 81
# 3617

# %% [markdown]
# ##Panel for years 2001-2006

# %%
panel_01_06 = []

for s in ['01', '02', '03', '04', '05', '06']:
    filelist = glob.glob(BASE_DIR+f"docs/{s}-*.xml")
    filelist_E = glob.glob(BASE_DIR+f"docs/E{s[1]}*.xml")
    print(f"year: {s}, # of files: {len(filelist) + len(filelist_E)}")
    for filename in tqdm(filelist + filelist_E):
        with open(filename, encoding="utf-8") as open_file:
            content = open_file.read()
            
            soup = BeautifulSoup(content, "xml")
            panel_01_06.append(soup.find('SUBJECT').get_text())
            # use soup to get all paragraphs in <SUM> tags
            if soup.find('SUM') is not None:
                panel_01_06.append(soup.find('SUM').get_text())
            # if soup.find('SUPLINF') is not None:
            #     panel_01_06.append(soup.find('SUPLINF').get_text())
            # print(filename)
            # print(soup.find('SUBJECT').get_text())
            # print(soup.find('SUM').get_text())
            
            #print(soup.find('SUPLINF').get_text())

            #print("First SUBJECT tag in " + filename + ": " + str(soup.find('SUBJECT')))
# Out:
# year: 01, # of files: 170
# 100%|██████████| 170/170 [00:04<00:00, 39.95it/s]
# year: 02, # of files: 135
# 100%|██████████| 135/135 [00:04<00:00, 31.37it/s]
# year: 03, # of files: 156
# 100%|██████████| 156/156 [00:05<00:00, 30.16it/s]
# year: 04, # of files: 167
# 100%|██████████| 167/167 [00:06<00:00, 26.12it/s]
# year: 05, # of files: 120
# 100%|██████████| 120/120 [00:04<00:00, 28.17it/s]
# year: 06, # of files: 125
# 100%|██████████| 125/125 [00:03<00:00, 32.90it/s]

# %% [markdown]
# ##Panel for years 2007-2012

# %%
panel_07_12 = []
for s in ['07', '08', '09']:
    filelist = glob.glob(BASE_DIR+f"docs/{s}-*.xml")
    filelist_E = glob.glob(BASE_DIR+f"docs/E{s[1]}*.xml")

    print(f"year: {s}, # of files: {len(filelist) + len(filelist_E)}")
    for filename in tqdm(filelist + filelist_E):
        with open(filename, encoding="utf-8") as open_file:
            content = open_file.read()
            
            soup = BeautifulSoup(content, "xml")
            panel_07_12.append(soup.find('SUBJECT').get_text())
            if soup.find('SUM') is not None:
                panel_07_12.append(soup.find('SUM').get_text())
            ## if soup.find('SUPLINF') is not None:
            ##    panel_07_12.append(soup.find('SUPLINF').get_text())

for i in range(2010, 2013):
    s = str(i)
    filelist = glob.glob(BASE_DIR+f"docs/{s}-*.xml")
    filelist += glob.glob(BASE_DIR+f"docs/C1-{s}-*.xml")
    filelist += glob.glob(BASE_DIR+f"docs/C2-{s}-*.xml")
    filelist += glob.glob(BASE_DIR+f"docs/R1-{s}-*.xml")

    print(f"year: {s}, # of files: {len(filelist)}")
    for filename in tqdm(filelist):
        with open(filename, encoding="utf-8") as open_file:
            content = open_file.read()
            
            soup = BeautifulSoup(content, "xml")
            panel_07_12.append(soup.find('SUBJECT').get_text())
            if soup.find('SUM') is not None:
                panel_07_12.append(soup.find('SUM').get_text())
            # if soup.find('SUPLINF') is not None:
            #     panel_07_12.append(soup.find('SUPLINF').get_text())
# Out:
# year: 07, # of files: 141
# 100%|██████████| 141/141 [00:05<00:00, 26.64it/s]
# year: 08, # of files: 163
# 100%|██████████| 163/163 [00:06<00:00, 26.45it/s]
# year: 09, # of files: 164
# 100%|██████████| 164/164 [00:06<00:00, 23.88it/s]
# year: 2010, # of files: 201
# 100%|██████████| 201/201 [00:11<00:00, 17.40it/s]
# year: 2011, # of files: 253
# 100%|██████████| 253/253 [00:15<00:00, 16.42it/s]
# year: 2012, # of files: 203
# 100%|██████████| 203/203 [00:12<00:00, 16.70it/s]

# %% [markdown]
# ##Topic Model using Latent Dirichlet Allocation

# %%
N_TOPICS = 20
MAX_FEATURES = 10000
RANDOM_STATE = 42
N_TOP_WORDS = 10

A_vec = CountVectorizer(max_features = MAX_FEATURES, # only top 10k words by freq
                        lowercase = True,            # remove capitalization
                        ngram_range = (1,2),         # include 1, 2-word phrases
                        min_df=10,   # note: absolute count of documents
                        max_df=0.95, # note: % of docs
                        stop_words='english'
                        )

def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        term_list = [feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        print("topic %d:" % (topic_idx), term_list)

def process_panel(panel):
    A_vec_tf = A_vec.fit_transform(panel) # A_vec_tf is a sparse matrix
    tf_feature_names_A = A_vec.get_feature_names()

    # This will take a couple of minutes to run...
    lda = LatentDirichletAllocation(n_components=N_TOPICS, random_state=RANDOM_STATE)
    lda.fit(A_vec_tf)
    topic_models = lda.components_
    display_topics(lda, tf_feature_names_A, N_TOP_WORDS)

# %% [markdown]
# ##20 Topics and Top 10 words from panel for years 2001-2006

# %%
process_panel(panel_01_06)
# Out:
# topic 0: ['form', 'amendments', 'rule', 'disclosure', 'securities', 'registration', 'summary', 'technical', 'insurance', 'fees']
# topic 1: ['capital', 'risk', 'banks', 'based', 'risk based', 'banking', 'based capital', 'bank', 'foreign', 'guidelines']
# topic 2: ['edgar', 'manual', 'filer', 'filer manual', 'filing', 'electronic', 'commission', 'securities', 'electronic filing', 'revisions']
# topic 3: ['annual', 'reports', 'rules', 'published', 'amendments', 'fr', 'annual reports', 'accelerated', 'report', 'summary']
# topic 4: ['act', 'disclosure', 'directors', 'rules', '2002', 'sarbanes oxley', 'oxley act', 'sarbanes', 'oxley', 'executive']
# topic 5: ['audit', 'board', 'rules', 'rule', 'lending', 'act', 'truth', 'certain', 'services', 'disclosures']
# topic 6: ['commission', 'financial', 'rule', 'securities', 'exchange', 'section', 'rules', 'amendments', 'accounting', 'summary']
# topic 7: ['fdic', 'insurance', 'deposit', 'deposit insurance', 'federal', 'comment', 'act', 'federal deposit', 'rule', 'proposed']
# topic 8: ['institutions', 'depository', 'million', 'statement', 'reserve', 'requirements', 'institution', 'depository institutions', 'regulatory', 'insured']
# topic 9: ['internal', 'financial', 'reporting', 'financial reporting', 'control', 'internal control', 'management', 'control financial', 'disclosure', 'report']
# topic 10: ['board', 'holding', 'bank', 'rule', 'federal', 'final rule', 'final', 'bank holding', 'holding companies', 'companies']
# topic 11: ['securities', 'exchange', 'commission', 'act', 'securities exchange', 'exchange act', '1934', 'act 1934', 'exchange commission', 'section']
# topic 12: ['regulation', 'board', 'credit', 'summary', 'final', 'summary board', 'rate', 'reserve', 'commentary', 'federal']
# topic 13: ['funds', 'rule', 'amendments', 'commission', 'fund', 'investment', 'advisers', 'certain', 'securities', 'mutual']
# topic 14: ['futures', 'commission', 'trading', 'rules', 'commodity', 'security', 'act', 'commodity futures', 'security futures', 'exchange']
# topic 15: ['national', 'occ', 'banks', 'activities', 'national banks', 'bank', 'rule', 'national bank', 'comptroller', 'program']
# topic 16: ['act', 'information', 'agencies', 'section', 'consumer', 'credit', 'regulations', 'summary', 'financial', 'fair']
# topic 17: ['commission', 'commodity', 'futures', 'trading', 'certain', 'trading commission', 'futures trading', 'commodity futures', 'commission commission', 'summary commodity']
# topic 18: ['investment', 'company', 'investment company', 'companies', 'act', 'securities', 'investment companies', 'management', 'company act', 'amendments']
# topic 19: ['reserve', 'federal', 'federal reserve', 'office', 'banks', 'reserve banks', 'bank', 'reserve bank', 'board', 'extensions']

# %% [markdown]
# ##20 Topics and Top 10 words from panel for years 2007-2012

# %%
process_panel(panel_07_12)
# Out:
# topic 0: ['act', 'rules', 'consumer', 'final', 'financial', 'credit', 'regulation', 'board', 'final rules', 'electronic']
# topic 1: ['securities', 'swap', 'security', 'security based', 'act', 'rules', 'based', 'exchange', 'based swap', 'requirements']
# topic 2: ['commission', 'exchange', 'act', 'securities', 'exchange act', 'securities exchange', 'rule', 'market', 'exchange commission', 'summary']
# topic 3: ['rule', 'regulation', 'final', 'final rule', 'board', 'published', 'summary', 'federal register', 'federal', 'register']
# topic 4: ['capital', 'risk', 'federal', 'insurance', 'fdic', 'occ', 'deposit insurance', 'deposit', 'summary', 'office']
# topic 5: ['institutions', 'depository', 'fdic', 'depository institutions', 'institution', 'reserve', 'insured', 'rule', 'deposit', 'insured depository']
# topic 6: ['reserve', 'federal reserve', 'federal', 'board', 'office', 'bank', 'reserve bank', 'regulation', 'amendments', 'office federal']
# topic 7: ['disclosure', '2008', 'foreign', 'issuers', 'end', 'annual', 'credit', 'reports', 'statement', 'private']
# topic 8: ['act', 'frank', 'dodd', 'dodd frank', 'protection', 'consumer', 'reform', 'protection act', 'street', 'street reform']
# topic 9: ['board', 'credit', 'bank', 'company', 'stress', 'rule', 'reserve', 'companies', 'federal', 'holding']
# topic 10: ['commission', 'edgar', 'form', 'manual', 'filer', 'regulations', 'filing', 'electronic', 'filer manual', 'revisions']
# topic 11: ['act', 'date', 'certain', 'order', 'july', 'guidance', 'regulations', 'compliance', 'temporary', '2011']
# topic 12: ['credit', 'act', 'ratings', 'agencies', 'investment', 'company', 'credit ratings', 'investment company', 'rules', 'use']
# topic 13: ['consumer', 'bureau', 'proposed', 'act', 'credit', 'rating', 'financial', 'comment', 'consumer financial', 'rule']
# topic 14: ['lending', 'truth', 'act', 'truth lending', 'regulation', 'mortgage', 'loan', 'practices', 'tila', 'compensation']
# topic 15: ['securities', 'program', 'guarantee', 'asset', 'backed', 'rule', 'asset backed', 'backed securities', 'section', 'temporary']
# topic 16: ['commission', 'commodity', 'futures', 'act', 'trading', 'regulations', 'dodd frank', 'dodd', 'frank', 'commodity futures']
# topic 17: ['investment', 'commission', 'funds', 'advisers', 'investment advisers', 'act', 'rule', 'advisers act', 'fund', 'registered']
# topic 18: ['rule', 'securities', 'accounting', 'short', 'certain', 'financial', 'safe', 'harbor', 'safe harbor', 'summary']
# topic 19: ['comment', 'commission', 'period', 'proposed', 'rules', 'public', 'release', 'summary', '30', 'act']

# %% [markdown]
# ##Panel for years 2008, 2009, 2016, and 2017

# %%
panel_08 = []
for s in ['08']:
    filelist = glob.glob(BASE_DIR+f"docs/{s}-*.xml")
    filelist_E = glob.glob(BASE_DIR+f"docs/E{s[1]}*.xml")

    print(f"year: {s}, # of files: {len(filelist) + len(filelist_E)}")
    for filename in tqdm(filelist + filelist_E):
        with open(filename, encoding="utf-8") as open_file:
            content = open_file.read()
            
            soup = BeautifulSoup(content, "xml")
            panel_08.append(soup.find('SUBJECT').get_text())
            if soup.find('SUM') is not None:
                panel_08.append(soup.find('SUM').get_text())
            # if soup.find('SUPLINF') is not None:
            #     panel_08.append(soup.find('SUPLINF').get_text())
panel_09 = []
for s in ['09']:
    filelist = glob.glob(BASE_DIR+f"docs/{s}-*.xml")
    filelist_E = glob.glob(BASE_DIR+f"docs/E{s[1]}*.xml")

    print(f"year: {s}, # of files: {len(filelist) + len(filelist_E)}")
    for filename in tqdm(filelist + filelist_E):
        with open(filename, encoding="utf-8") as open_file:
            content = open_file.read()
            
            soup = BeautifulSoup(content, "xml")
            panel_09.append(soup.find('SUBJECT').get_text())
            if soup.find('SUM') is not None:
                panel_09.append(soup.find('SUM').get_text())
            # if soup.find('SUPLINF') is not None:
            #     panel_09.append(soup.find('SUPLINF').get_text())

panel_16 = []
for i in range(2016, 2017):
    s = str(i)
    filelist = glob.glob(BASE_DIR+f"docs/{s}-*.xml")
    filelist += glob.glob(BASE_DIR+f"docs/C1-{s}-*.xml")
    filelist += glob.glob(BASE_DIR+f"docs/C2-{s}-*.xml")
    filelist += glob.glob(BASE_DIR+f"docs/R1-{s}-*.xml")

    print(f"year: {s}, # of files: {len(filelist)}")
    for filename in tqdm(filelist):
        with open(filename, encoding="utf-8") as open_file:
            content = open_file.read()
            
            soup = BeautifulSoup(content, "xml")
            panel_16.append(soup.find('SUBJECT').get_text())
            if soup.find('SUM') is not None:
                panel_16.append(soup.find('SUM').get_text())
            # if soup.find('SUPLINF') is not None:
            #     panel_16.append(soup.find('SUPLINF').get_text())

panel_17 = []
for i in range(2017, 2018):
    s = str(i)
    filelist = glob.glob(BASE_DIR+f"docs/{s}-*.xml")
    filelist += glob.glob(BASE_DIR+f"docs/C1-{s}-*.xml")
    filelist += glob.glob(BASE_DIR+f"docs/C2-{s}-*.xml")
    filelist += glob.glob(BASE_DIR+f"docs/R1-{s}-*.xml")

    print(f"year: {s}, # of files: {len(filelist)}")
    for filename in tqdm(filelist):
        with open(filename, encoding="utf-8") as open_file:
            content = open_file.read()
            
            soup = BeautifulSoup(content, "xml")
            panel_17.append(soup.find('SUBJECT').get_text())
            if soup.find('SUM') is not None:
                panel_17.append(soup.find('SUM').get_text())
            # if soup.find('SUPLINF') is not None:
            #     panel_17.append(soup.find('SUPLINF').get_text())
# Out:
# year: 08, # of files: 163
# 100%|██████████| 163/163 [00:05<00:00, 31.46it/s]
# year: 09, # of files: 164
# 100%|██████████| 164/164 [00:05<00:00, 28.42it/s]
# year: 2016, # of files: 189
# 100%|██████████| 189/189 [00:51<00:00,  3.65it/s]
# year: 2017, # of files: 128
# 100%|██████████| 128/128 [00:29<00:00,  4.40it/s]

# %% [markdown]
# ##20 Topics and Top 10 words for 2008

# %%
process_panel(panel_08)
# Out:
# topic 0: ['funds', 'collection', 'availability', 'investment', 'checks', 'truth', 'truth lending', 'lending', 'electronic', 'company act']
# topic 1: ['federal', 'reserve', 'federal reserve', 'office', 'bank', 'board', 'reserve bank', 'amending', 'processing', 'regulation']
# topic 2: ['capital', 'corporation', 'banks', 'exemption', 'comment', 'regulatory', 'certain', 'federal', 'relating', 'collectively']
# topic 3: ['commission', 'futures', 'commodity', 'trading', 'regulations', 'commodity futures', 'futures trading', 'trading commission', 'commission commission', 'contracts']
# topic 4: ['foreign', 'private', 'issuers', 'foreign private', 'financial', 'information', 'amendments', 'rules', 'revisions', 'form']
# topic 5: ['investment', 'commission', 'securities', 'act', 'company', 'exchange', 'securities exchange', 'investment company', 'rules', 'exchange commission']
# topic 6: ['act', 'rule', 'final', 'board', 'final rule', '2008', 'federal', 'mortgage', 'consumer', 'proposed']
# topic 7: ['board', 'reserve', 'federal reserve', 'federal', 'rate', 'credit', 'governors federal', 'board governors', 'governors', 'bank']
# topic 8: ['program', 'temporary', 'certain', 'lending', 'money', 'market', 'interim', 'funds', 'rule', 'interim final']
# topic 9: ['capital', 'risk', 'rule', 'final', 'interim', 'final rule', 'interim final', 'based', 'risk based', 'guidelines']
# topic 10: ['commission', 'amendments', 'entities', 'registered', 'information', 'markets', 'procedures', 'regulation', 'amend', 'persons']
# topic 11: ['reserve', 'regulation', 'institutions', 'depository', 'federal reserve', 'requirements', 'federal', 'depository institutions', 'reserve requirements', 'requirements depository']
# topic 12: ['occ', 'fdic', 'bank', 'office', 'national', 'financial', 'summary', 'regulations', 'amending', 'federal']
# topic 13: ['fdic', 'insurance', 'deposit insurance', 'deposit', 'accounts', 'rule', 'regulations', 'summary fdic', 'interim', 'financial']
# topic 14: ['institution', 'depository', 'rule', 'fdic', 'insured', 'institutions', 'insured depository', 'deposit', 'depository institutions', 'depository institution']
# topic 15: ['commission', 'authority', '30', 'exchange', 'security', 'securities', 'rules', 'registration', 'related', 'office']
# topic 16: ['federal', 'rules', 'proposed', 'published', '2008', 'federal register', 'register', 'fr', 'submitted', 'rulemaking']
# topic 17: ['assessment', 'period', 'comment', '2009', '2008', 'guidance', 'effective', 'risk', 'proposed', 'practices']
# topic 18: ['securities', 'exchange', 'act', 'exchange act', 'rule', 'commission', 'securities exchange', 'proposed', 'information', '1934']
# topic 19: ['regulation', 'act', 'rules', 'proposed', 'credit', 'consumer', 'financial', 'board', 'reporting', 'provide']

# %% [markdown]
# ##20 Topics and Top 10 words for 2009

# %%
process_panel(panel_09)
# Out:
# topic 0: ['2009', 'published', 'federal register', 'register', 'federal', 'fr', '74', '74 fr', 'rule', 'document']
# topic 1: ['credit', 'regulation', 'board', 'consumer', 'act', 'final', 'disclosures', 'summary', 'requirements', 'end']
# topic 2: ['commission', 'rule', 'securities', 'exchange', 'amendments', 'act', 'regulation', 'public', 'securities exchange', 'proposed']
# topic 3: ['funds', 'availability', 'collection', 'checks', 'certain', 'transactions', 'banks', 'exemption', 'designed', 'securities']
# topic 4: ['securities', 'act', 'exchange act', 'exchange', 'securities act', 'rules', '1934', 'act 1934', 'amendments', '1933']
# topic 5: ['capital', 'bank', 'companies', 'holding', 'board', 'rule', 'securities', 'final', '2008', 'final rule']
# topic 6: ['rule', 'interim', 'final', 'final rule', 'insurance', 'deposit', '2009', '2010', 'deposit insurance', 'institution']
# topic 7: ['accounting', 'commission', 'release', 'financial', 'standards', 'staff', 'securities', 'guidance', '2008', '2009']
# topic 8: ['fdic', 'certain', 'deposit', 'section', 'amendment', 'act', 'final rule', 'federal', 'insurance', 'final']
# topic 9: ['guarantee', 'program', 'debt', 'fdic', 'guarantee program', 'temporary', 'liquidity', 'emergency', 'liquidity guarantee', 'temporary liquidity']
# topic 10: ['credit', 'rating', 'ratings', 'amendments', 'commission', 'rule', 'proposing', 'information', 'disclosure', 'organizations']
# topic 11: ['information', 'reporting', 'account', 'rules', 'financial', 'data', 'commission', 'summary', 'section', 'report']
# topic 12: ['rate', 'depository', 'institutions', 'insured', 'depository institutions', 'insured depository', 'affiliate', 'restrictions', 'fdic', 'marketing']
# topic 13: ['agencies', 'act', 'capital', 'guidelines', 'loans', 'mortgage', 'institutions', 'collectively', 'based', 'loan']
# topic 14: ['reserve', 'federal reserve', 'federal', 'board', 'office', 'bank', 'reserve bank', 'regulation', 'institutions', 'amendments']
# topic 15: ['2008', 'rules', 'disclosures', 'act', 'final', 'requirements', 'procedures', 'amended', 'transaction', 'new']
# topic 16: ['commission', 'regulations', 'general', 'comment', 'act', 'accounts', 'period', 'issued', 'request', 'summary']
# topic 17: ['commission', 'commodity', 'futures', 'regulations', 'reports', 'annual', 'required', 'capital', 'financial', 'trading']
# topic 18: ['2009', 'risk', 'based', 'risk based', 'market', 'mutual', '30', 'revisions', 'assessments', 'institution']
# topic 19: ['disclosure', 'truth', 'lending', 'truth lending', 'occ', 'financial', 'electronic', 'act', 'fund', 'regulations']

# %% [markdown]
# ##20 Topics and Top 10 words for 2016

# %%
process_panel(panel_16)
# Out:
# topic 0: ['commission', 'commodity', 'futures', 'trading', 'commodity futures', 'regulations', 'trading commission', 'futures trading', 'cftc', 'commission cftc']
# topic 1: ['final', 'rule', 'act', 'final rule', 'rules', 'regulations', 'summary', 'interim final', 'interim', 'information']
# topic 2: ['rule', 'holding', 'assets', 'board', 'companies', 'bank', 'bank holding', 'holding companies', 'billion', 'foreign']
# topic 3: ['act', 'securities', 'exchange', 'exchange act', 'securities exchange', '1934', 'act 1934', 'title', 'requirements', 'rule']
# topic 4: ['institutions', 'insurance', 'deposit', 'insured', 'depository', 'fdic', 'depository institutions', 'insured depository', 'deposit insurance', 'institution']
# topic 5: ['requirements', 'disclosure', 'disclosure requirements', 'important', 'systemically important', 'systemically', 'registrants', 'amendments', 'certain', 'liquidity']
# topic 6: ['requirements', 'contracts', 'certain', 'recordkeeping', 'mortgage', 'guidance', 'compliance', 'regulations', 'section', 'determination']
# topic 7: ['inflation', 'act', 'civil', 'rule', 'adjustment', 'rules practice', 'practice', 'securities', '2015', 'amended']
# topic 8: ['swap', 'security', 'based', 'security based', 'based swap', 'commission', 'data', 'regulation', 'swap data', 'exchange']
# topic 9: ['regulation', 'act', 'lending', 'act regulation', 'truth lending', 'truth', 'exemption', 'lending act', 'mortgage', 'amendments']
# topic 10: ['act', 'frank', 'dodd', 'dodd frank', 'protection', 'consumer protection', 'consumer', 'frank act', 'wall street', 'street']
# topic 11: ['agencies', 'act', 'consumer', 'threshold', 'annual', 'increase', 'bureau', 'board', 'annual percentage', 'percentage']
# topic 12: ['commission', 'swap', 'amendments', 'form', 'adopting', 'commission adopting', 'requirements', 'rules', 'fund', 'certain']
# topic 13: ['companies', 'holding', 'capital', 'holding companies', 'activities', 'financial', 'risk', 'notice', 'capital requirements', 'requirements']
# topic 14: ['rule', 'commission', 'investment', 'order', 'securities', 'advisers', 'exchange commission', 'act', 'summary securities', 'securities exchange']
# topic 15: ['federal', 'savings', 'banks', 'associations', 'savings associations', 'occ', 'national', 'rules', 'national banks', 'fdic']
# topic 16: ['reserve', 'board', 'federal reserve', 'federal', 'governors', 'board governors', 'governors federal', 'summary board', 'bank', 'risk']
# topic 17: ['period', 'commission', 'comment', 'comment period', '2016', 'comments', 'clearing', 'time', 'additional', 'issues']
# topic 18: ['regulatory', 'capital', 'rules', 'regulatory capital', 'capital rules', 'flexibility', 'federal', 'reserve board', 'update', 'asset']
# topic 19: ['bureau', 'consumer', 'financial', 'consumer financial', 'protection', 'regulation', 'financial protection', 'bureau consumer', 'protection bureau', 'summary']

# %% [markdown]
# ##20 Topics and Top 10 words for 2017

# %%
process_panel(panel_17)
# Out:
# topic 0: ['amendments', 'proposed', 'proposed amendments', 'regulation', 'disclosure', 'certain', 'summary', 'proposing', 'requirements', 'order']
# topic 1: ['board', 'reserve', 'federal', 'federal reserve', 'summary board', 'stress', 'total', 'policy', 'summary', 'bank']
# topic 2: ['board', 'federal', 'reserve', 'rate', 'federal reserve', 'credit', 'regulation', 'amendments', 'summary board', 'reserve board']
# topic 3: ['financial', 'certain', 'requirements', 'contracts', 'qualified', 'related', 'fdic', 'institutions', 'definition', 'revisions']
# topic 4: ['commission', '2017', 'agenda', 'comment', 'summary', 'published', 'regulatory', 'period', 'register', 'publishing']
# topic 5: ['regulation', 'act', 'act regulation', 'truth lending', 'lending', 'truth', 'lending act', 'electronic', 'transfer', 'fund']
# topic 6: ['federal', 'final', 'covered', 'occ', 'banks', 'rule', 'fdic', 'final rule', 'board', 'deposit']
# topic 7: ['threshold', 'increase', 'exemption', 'annual', 'percentage', 'bureau', 'consumer', '2017', 'based', 'mortgage']
# topic 8: ['form', 'commission', 'regulations', 'act', 'data', 'required', 'information', 'funds', 'amendments', 'commission commission']
# topic 9: ['act', 'rule', 'inflation', 'final', 'adjustment', 'final rule', '2016', 'amending', 'federal', 'rules']
# topic 10: ['covered', 'bureau', 'consumer', 'rule', 'financial', 'consumer financial', 'financial protection', 'final rule', 'protection', 'final']
# topic 11: ['regarding', 'information', 'request', 'rules', 'policy', 'changes', 'risk', 'public', 'federal', 'federal register']
# topic 12: ['capital', 'banking', 'organizations', 'banking organizations', 'rule', 'regulatory', 'assets', 'certain', 'proposed', 'final rule']
# topic 13: ['securities', 'act', 'exchange', 'securities exchange', 'amendments', 'exchange act', 'technical', 'adopting', 'inflation', 'adjustments']
# topic 14: ['commission', 'commodity', 'swap', 'futures', 'trading', 'regulations', 'summary', 'commodity futures', 'trading commission', 'futures trading']
# topic 15: ['settlement', 'real', 'real estate', 'estate', 'act', 'procedures', 'securities', 'mortgage', 'guidance', 'rules']
# topic 16: ['requirements', 'institutions', 'depository', 'reserve', 'depository institutions', 'holding', 'bank holding', 'regulation', 'requirements depository', 'reserve requirements']
# topic 17: ['bureau', 'consumer', 'rule', 'regulation', 'financial', 'protection', 'financial protection', 'consumer financial', 'protection bureau', 'bureau consumer']
# topic 18: ['rules', 'subject', 'final', 'amendments', 'provisions', 'capital', 'adopting', '2018', 'reporting', 'proposal']
# topic 19: ['act', 'dodd frank', 'frank', 'dodd', 'consumer', 'frank act', 'protection act', 'reform', 'protection', 'reform consumer']

# %% [markdown]
# ##Panel for years 2020-2021

# %%
panel_20_21 = []
for i in range(2020, 2021):
    s = str(i)
    filelist = glob.glob(BASE_DIR+f"docs/{s}-*.xml")
    filelist += glob.glob(BASE_DIR+f"docs/C1-{s}-*.xml")
    filelist += glob.glob(BASE_DIR+f"docs/C2-{s}-*.xml")
    filelist += glob.glob(BASE_DIR+f"docs/R1-{s}-*.xml")

    print(f"year: {s}, # of files: {len(filelist)}")
    for filename in tqdm(filelist):
        with open(filename, encoding="utf-8") as open_file:
            content = open_file.read()
            
            soup = BeautifulSoup(content, "xml")
            panel_20_21.append(soup.find('SUBJECT').get_text())
            if soup.find('SUM') is not None:
                panel_20_21.append(soup.find('SUM').get_text())
# Out:
# year: 2020, # of files: 286
# 100%|██████████| 286/286 [01:20<00:00,  3.54it/s]

# %% [markdown]
# ##20 Topics and Top 10 words for 2020-21

# %%
process_panel(panel_20_21)
# Out:
# topic 0: ['loan', 'qm', 'reporting', 'data', 'requirements', 'temporary', 'mortgage', 'loans', 'definition', 'regulation']
# topic 1: ['commission', 'amendments', 'certain', 'regulation', 'exemption', 'commodity', 'disclosure', 'investors', 'summary', 'adopting']
# topic 2: ['investment', 'companies', 'investment companies', 'certain', 'funds', 'technical', 'end', 'clearing', 'exempt', 'requirement']
# topic 3: ['reserve', 'institutions', 'depository', 'regulation', 'depository institutions', 'federal', 'requirements', 'federal reserve', 'reserve requirements', 'board']
# topic 4: ['fdic', 'insurance', 'insured', 'deposit', 'federal', 'regarding', 'policy', 'summary', 'regulations', 'deposit insurance']
# topic 5: ['period', 'comment', '2020', 'proposed', 'notice', 'comment period', 'rulemaking', 'notice proposed', 'proposed rulemaking', 'extension']
# topic 6: ['securities', 'exchange', 'commission', 'securities exchange', 'exchange commission', 'rules', 'act', 'summary securities', 'issuers', 'summary']
# topic 7: ['credit', 'financial', 'disclosure', 'credit losses', 'losses', 'act', 'information', 'summary', 'analysis', 'community']
# topic 8: ['rules', 'trading', 'execution', 'commission', 'market', 'regulations', 'final rules', 'final', 'facilities', 'electronic']
# topic 9: ['board', 'rate', 'act', 'fair', 'fund', 'federal', 'rule', 'summary', 'governors', 'board governors']
# topic 10: ['act', 'frank', 'dodd frank', 'dodd', 'consumer', 'debt', 'frank act', 'protection act', 'protection', 'street']
# topic 11: ['savings', 'regulations', 'banks', 'savings associations', 'associations', 'occ', 'federal', 'national', 'threshold', 'state']
# topic 12: ['rule', 'board', 'final', 'final rule', 'federal', 'company', 'banking', 'deposit insurance', 'deposit', 'bank']
# topic 13: ['bureau', 'consumer', 'financial', 'consumer financial', 'protection', 'financial protection', 'protection bureau', 'bureau consumer', 'regulation', 'summary']
# topic 14: ['act', 'securities', 'rule', 'commission', 'exchange', 'investment', 'information', 'company', 'regulation', 'form']
# topic 15: ['commission', 'commodity', 'amendments', 'regulations', 'summary', 'form', 'futures', 'commission commission', 'commodity futures', 'futures trading']
# topic 16: ['companies', 'holding', 'definition', 'act', 'holding companies', 'loan', 'regulation', 'lending', 'truth lending', 'truth']
# topic 17: ['rule', 'final', 'final rule', 'interim', 'interim final', 'federal', 'agencies', 'ratio', 'board', 'leverage']
# topic 18: ['capital', 'regulatory', 'regulatory capital', 'large', 'assessment', 'transition', 'proposal', 'rule', 'certain', 'requirements']
# topic 19: ['swap', 'margin', 'requirements', 'rule', 'commission', 'cftc', 'swaps', 'dealers', 'swap dealers', 'participants']

# %% [markdown]
# ##Non negative Matrix Factorization

# %%
A_vec = TfidfVectorizer(max_features = 10000, # only top 10k words by freq
                        lowercase = True,     # remove capitalization
                        ngram_range = (1,2),  # include 1, 2-word phrases
                        min_df=10,   # note: absolute count of documents
                        max_df=0.95, # note: % of docs
                        stop_words='english'
                        )
tfidf_documents = A_vec.fit_transform(panel_20_21)
tfidf_feature_names = A_vec.get_feature_names()

nmf = NMF(n_components=N_TOPICS, random_state=RANDOM_STATE, init="nndsvd")
W = nmf.fit_transform(tfidf_documents) 
H = nmf.components_

for topic_index in range(N_TOPICS):
    top_indices = np.argsort(H[topic_index, :])[::-1]
    top_terms = []
    for term_index in top_indices[0:N_TOP_WORDS]:
        top_terms.append(tfidf_feature_names[term_index])
    print("topic ", topic_index, top_terms)
# Out:
# topic  0 ['rule', 'final', 'final rule', 'board', 'federal', 'interim', 'interim final', 'agencies', '2020', 'federal reserve']
# topic  1 ['commission', 'commodity', 'trading', 'futures', 'futures trading', 'commodity futures', 'trading commission', 'summary commodity', 'cftc', 'regulations']
# topic  2 ['swap', 'margin', 'dealers', 'swap dealers', 'swap participants', 'major', 'major swap', 'dealers major', 'participants', 'swaps']
# topic  3 ['bureau', 'consumer', 'consumer financial', 'protection', 'financial', 'bureau consumer', 'protection bureau', 'financial protection', 'summary bureau', 'act']
# topic  4 ['reserve', 'depository', 'institutions', 'depository institutions', 'reserve requirements', 'requirements depository', 'regulation reserve', 'regulation', 'federal reserve', 'requirements']
# topic  5 ['federal savings', 'banks', 'national', 'savings', 'national banks', 'savings associations', 'associations', 'banks federal', 'federal', 'activities']
# topic  6 ['regulation', 'definition', 'truth lending', 'truth', 'mortgage', 'lending', 'act regulation', 'qm', 'lending act', 'loan']
# topic  7 ['securities', 'commission', 'exchange', 'securities exchange', 'act', 'rules', 'exchange commission', 'exchange act', 'summary securities', 'information']
# topic  8 ['regulations', 'fdic', 'state', 'transferred', 'state savings', 'ots', 'removal', 'associations', 'savings associations', 'deposit']
# topic  9 ['period', 'comment', 'comment period', '2020', 'extension', 'extension comment', 'proposed', 'proposal', 'published', 'notice']
# topic  10 ['community reinvestment', 'reinvestment act', 'reinvestment', 'community', 'act', 'regulations', 'board', 'act regulation', 'bank', 'thresholds']
# topic  11 ['companies', 'holding', 'holding companies', 'loan', 'bank', 'bank holding', 'savings loan', 'banking', 'banking organizations', 'loan holding']
# topic  12 ['swap', 'data', 'reporting', 'execution', 'swap data', 'reporting requirements', 'swap execution', 'requirements', 'facilities', 'execution facilities']
# topic  13 ['capital', 'regulatory', 'regulatory capital', 'capital rule', 'transition', 'rule', 'losses', 'credit losses', 'credit', 'flexibility']
# topic  14 ['investment', 'funds', 'investment companies', 'fund', 'private', 'company', 'companies', 'investment company', 'term', 'act']
# topic  15 ['debt', 'collection', 'debt collection', 'collection practices', 'regulation', 'practices', 'money', 'procedures', 'fair', 'electronic']
# topic  16 ['amendments', 'temporary', 'adopting amendments', 'disclosures', 'proposed', 'businesses', 'investors', 'financial', 'form', 'adopting']
# topic  17 ['policy', 'statement', 'regarding', 'information', 'statement policy', 'guidance', 'compliance', 'rules', 'supervisory', 'depository']
# topic  18 ['options', 'foreign futures', 'foreign', 'transactions', 'futures', 'exemption', 'certain', 'registration', 'real', 'real estate']
# topic  19 ['disclosure', 'updated', 'contracts', 'disclosure requirements', 'insurance', 'requirements', 'correction', 'summary', 'information', 'approach']
